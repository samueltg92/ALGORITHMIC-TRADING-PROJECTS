# %%
# %matplotlib inline
import quantstats as qs
import pandas as pd
import numpy as np

# %%
roboforex = pd.read_excel('reporte_modificable.xlsx')
roboforex.head()
# Out:
#    Balance inicial       Time  Symbol  Balance  Peak Balance  DD Value  \
# 0           3000.0 2022-05-24  EURUSD  3000.00        3000.0      0.00
# 1              NaN 2022-05-24  EURUSD  2999.99        3000.0     -0.01
# 2              NaN 2022-05-24  EURUSD  2999.98        3000.0     -0.02
# 3              NaN 2022-05-24  EURUSD  2999.96        3000.0     -0.04
# 4              NaN 2022-05-24  EURUSD  2999.93        3000.0     -0.07
#
#    DD Rel/Dia %  DD Max %  Profit  Profit% Diario        Mes  Balance Mensual  \
# 0      0.000000  0.063643     0.0             0.0 2022-04-30             0.00
# 1      0.000003       NaN     0.0             0.0 2022-05-01          3054.25
# 2      0.000007       NaN     0.0             0.0 2022-06-01          3903.79
# 3      0.000013       NaN     0.0             0.0 2022-07-01          4549.57
# 4      0.000023       NaN     0.0             0.0        NaT              NaN
#
#    Profit Mensual  Profit Mensual %  DD Max Mensual % Symbol indv.  \
# ...

# %%
roboforex['Time'] = pd.to_datetime(roboforex['Time'])

# %%
roboforex = roboforex.set_index('Time')

# %%
qs.reports.full(roboforex['Balance'])
# Out:
# <h4>Performance Metrics</h4>
#                            Strategy
# -------------------------  ----------
# Start Period               2022-05-24
# End Period                 2022-07-22
# Risk-Free Rate             0.0%
# Time in Market             100.0%
#
# Cumulative Return          51.65%
# CAGR﹪                     1214.66%
#
# Sharpe                     1.14
# Prob. Sharpe Ratio         98.59%
# Smart Sharpe               0.73
# Sortino                    1.88
# Smart Sortino              1.21
# Sortino/√2                 1.33
# Smart Sortino/√2           0.85
# Omega                      1.68
#
# Max Drawdown               -6.36%
# Longest DD Days            3
# Volatility (ann.)          11.23%
# Calmar                     190.85
# Skew                       1.87
# Kurtosis                   42.43
#
# Expected Daily %           0.05%
# Expected Monthly %         14.89%
# Expected Yearly %          51.65%
# Kelly Criterion            14.71%
# Risk of Ruin               0.0%
# ...
