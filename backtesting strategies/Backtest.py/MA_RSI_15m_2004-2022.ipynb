# %%
import pandas as pd
import talib as TA
import pandas_ta as ta
import matplotlib.pyplot as plt
from backtesting import Strategy, Backtest

# %%
'''
This strategy takes into account RSI for entry signals and a exponential moving average for trend detection.
is intended to be used with a 15m timeframe, but can be used with any timeframe, just test it out.
The backtest is done with backtesting.py and is intended to throw the results from it, the results are going to be optimized.
'''
# Out:
# '\nThis strategy takes into account RSI for entry signals and a exponential moving average for trend detection.\nis intended to be used with a 15m timeframe, but can be used with any timeframe, just test it out.\nThe backtest is done with backtesting.py and is intended to throw the results from it, the results are going to be optimized.\n'

# %% [markdown]
# READ & CLEAN THE DATA SET

# %%
df = pd.read_csv('data_sets/EURUSD_Candlestick_15_M_BID_09.04.2004-04.04.2022.csv')
df = df[df['Volume']!=0]
df.drop(columns=['Unnamed: 0'], inplace=True)
df.reset_index(drop=True, inplace=True)
df
# Out:
#                               Local time     Open     High      Low    Close  \
# 0       09.04.2004 00:00:00.000 GMT-0500  1.20722  1.20820  1.20689  1.20794
# 1       09.04.2004 00:15:00.000 GMT-0500  1.20796  1.20855  1.20752  1.20824
# 2       09.04.2004 00:30:00.000 GMT-0500  1.20817  1.20838  1.20767  1.20790
# 3       09.04.2004 00:45:00.000 GMT-0500  1.20807  1.20834  1.20719  1.20820
# 4       09.04.2004 01:00:00.000 GMT-0500  1.20780  1.20941  1.20773  1.20888
# ...                                  ...      ...      ...      ...      ...
# 449188  04.04.2022 17:45:00.000 GMT-0500  1.09742  1.09742  1.09717  1.09724
# 449189  04.04.2022 18:00:00.000 GMT-0500  1.09727  1.09735  1.09716  1.09722
# 449190  04.04.2022 18:15:00.000 GMT-0500  1.09722  1.09730  1.09710  1.09723
# 449191  04.04.2022 18:30:00.000 GMT-0500  1.09723  1.09761  1.09722  1.09745
# 449192  04.04.2022 18:45:00.000 GMT-0500  1.09746  1.09757  1.09726  1.09749
#
#          Volume
# 0       7953.20
# 1       7377.60
# 2       8624.70
# 3       6816.70
# 4       8339.30
# ...         ...
# 449188   154.88
# 449189   148.93
# 449190   199.63
# 449191   184.76
# 449192   254.23
#
# [449193 rows x 6 columns]

# %% [markdown]
# SLICING THE DATASET

# %%
#60% of the dataset
df60 = df[0:270000]  
#40% of the dataset
df40 = df[270000:449192]  
df60.dropna()
df40.dropna()
# Out:
#                               Local time     Open     High      Low    Close  \
# 270000  27.01.2015 04:30:00.000 GMT-0500  1.13079  1.13284  1.13065  1.13231
# 270001  27.01.2015 04:45:00.000 GMT-0500  1.13230  1.13289  1.13168  1.13179
# 270002  27.01.2015 05:00:00.000 GMT-0500  1.13179  1.13182  1.13090  1.13096
# 270003  27.01.2015 05:15:00.000 GMT-0500  1.13096  1.13124  1.12828  1.12857
# 270004  27.01.2015 05:30:00.000 GMT-0500  1.12857  1.13041  1.12821  1.12907
# ...                                  ...      ...      ...      ...      ...
# 449187  04.04.2022 17:30:00.000 GMT-0500  1.09740  1.09748  1.09729  1.09739
# 449188  04.04.2022 17:45:00.000 GMT-0500  1.09742  1.09742  1.09717  1.09724
# 449189  04.04.2022 18:00:00.000 GMT-0500  1.09727  1.09735  1.09716  1.09722
# 449190  04.04.2022 18:15:00.000 GMT-0500  1.09722  1.09730  1.09710  1.09723
# 449191  04.04.2022 18:30:00.000 GMT-0500  1.09723  1.09761  1.09722  1.09745
#
#          Volume
# 270000  2730.35
# 270001  3129.66
# 270002  2457.01
# 270003  3637.84
# 270004  3225.63
# ...         ...
# 449187   145.72
# 449188   154.88
# 449189   148.93
# 449190   199.63
# 449191   184.76
#
# [179192 rows x 6 columns]

# %% [markdown]
# BACKTEST USING ATR RELATED SL&TP

# %%
class MyStrat(Strategy):
    ema_window = 200
    rsi_window = 2
    atr_window = 14
    riskpct = 0.2
    
    def init(self):
        super().init()
        self.ema = self.I(TA.EMA, self.data.Close, self.ema_window)
        self.rsi = self.I(TA.RSI, self.data.Close, self.rsi_window)   
        self.atr = self.I(TA.ATR, self.data.Close, self.data.High, self.data.Low, self.atr_window) 

    def next(self):
        super().next()
        slatr = 1.2*self.atr[-1]
        TPSLRatio = 2
        price = self.data.Close[-1] 
        
        if self.position:
            self.position.close()
            
        if self.data.Close >= self.ema and self.rsi <= 10:
            sl1 = price - slatr
            tp1 = price + slatr*TPSLRatio    # 1e-4 is 1 pip
             
            
            self.buy(sl=sl1, tp=tp1, size= self.riskpct)
            
        if self.data.Close <= self.ema and self.rsi >= 90:
            sl2 = price + slatr
            tp2 = price - slatr*TPSLRatio    # 1e-4 is 1 pip
            
                                    
            self.sell(sl=sl2, tp=tp2, size= self.riskpct)

bt = Backtest(df40, MyStrat, cash=100, margin=1/50, commission = 0.00, trade_on_close=False)
stat = bt.run()
print(stat)
trades_size = stat['_trades']#['Size'] 
print(trades_size) # shows the size of the trades
#plt.bar(trades_size, height=trades_size.count())
#plot = bt.plot(plot_volume=False)
#print(plot)
# Out:
# /tmp/ipykernel_1635/964484283.py:36: UserWarning: Data index is not datetime. Assuming simple periods, but `pd.DateTimeIndex` is advised.
#   bt = Backtest(df40, MyStrat, cash=100, margin=1/50, commission = 0.00, trade_on_close=False)
# Start                                270000.0
# End                                  449191.0
# Duration                             179191.0
# Exposure Time [%]                   13.179718
# Equity Final [$]                  2227.774319
# Equity Peak [$]                   2365.305383
# Return [%]                        2127.774319
# Buy & Hold Return [%]               -3.078662
# Return (Ann.) [%]                         0.0
# Volatility (Ann.) [%]                     NaN
# Sharpe Ratio                              NaN
# Sortino Ratio                             NaN
# Calmar Ratio                              0.0
# Max. Drawdown [%]                  -22.910704
# Avg. Drawdown [%]                   -0.997274
# Max. Drawdown Duration                15821.0
# Avg. Drawdown Duration             251.876147
# # Trades                              15239.0
# Win Rate [%]                        53.258088
# Best Trade [%]                        0.47816
# Worst Trade [%]                     -0.276131
# Avg. Trade [%]                       0.002131
# Max. Trade Duration                       1.0
# Avg. Trade Duration                  0.966927
# Profit Factor                         1.15141
# Expectancy [%]                       0.002141
# SQN                                  4.137469
# _strategy                             MyStrat
# _equity_curve                          Equ...
# _trades                           Size  En...
# dtype: object
#         Size  EntryBar  ExitBar  EntryPrice  ExitPrice        PnL  ReturnPct  \
# 0       -883       236      237     1.13172   1.131820  -0.088300  -0.000088
# 1       -882       237      238     1.13182   1.132470  -0.573300  -0.000574
# 2        877       261      262     1.13259   1.133010   0.368340   0.000371
# 3        880       279      280     1.13265   1.132420  -0.202400  -0.000203
# 4       -879       377      378     1.13147   1.131590  -0.105480  -0.000106
# ...      ...       ...      ...         ...        ...        ...        ...
# 15234 -19918    179099   179100     1.10505   1.105180  -2.589340  -0.000118
# 15235 -19892    179100   179101     1.10518   1.104900   5.569760   0.000253
# 15236 -19942    179111   179112     1.10524   1.104880   7.179120   0.000326
# 15237 -20009    179121   179121     1.10509   1.104245  16.905379   0.000765
# 15238 -20304    179187   179188     1.09740   1.097420  -0.406080  -0.000018
#
#        EntryTime  ExitTime  Duration
# 0         270236    270237         1
# 1         270237    270238         1
# 2         270261    270262         1
# 3         270279    270280         1
# 4         270377    270378         1
# ...          ...       ...       ...
# 15234     449099    449100         1
# 15235     449100    449101         1
# 15236     449111    449112         1
# 15237     449121    449121         0
# 15238     449187    449188         1
#
# [15239 rows x 10 columns]

# %% [markdown]
# BACKTEST USING SIZE CALCULATION BY RISK% AND SL SIZE

# %%
# class MyStrat(Strategy):
#     ema_window = 200
#     rsi_window = 2
#     riskpct = 0.02
#     contract_size = 100000
    
#     def init(self):
#         super().init()
#         self.ema = self.I(TA.EMA, self.data.Close, self.ema_window)
#         self.rsi = self.I(TA.RSI, self.data.Close, self.rsi_window)   

#     def next(self):
#         super().next()
        
#         if self.position:
#             self.position.close()
            
#         if self.data.Close >= self.ema and self.rsi <= 10:
#             o, h, l, c = self.data.Open[-1], self.data.High[-1], self.data.Low[-1], self.data.Close[-1]
#             size1 = (self.equity*self.riskpct)//(o - l)*self.contract_size     
            
#             self.buy(limit=c, sl=l-4e-4, tp=c + 2*(c-1), size=int(size1))
            
#         if self.data.Close <= self.ema and self.rsi >= 90:
#             o, h, l, c = self.data.Open[-1], self.data.High[-1], self.data.Low[-1], self.data.Close[-1]
#             size2 = (self.equity*self.riskpct)//(h - c)*self.contract_size
                                    
#             self.sell(limit=c, sl=h+4e-4, tp=c - 2*(c-1), size=int(size2))

# bt = Backtest(df40, MyStrat, cash=100, margin=1/50, commission = 0.00, trade_on_close=False)
# stat = bt.run()
# print(stat)
#trades_size = stat['_trades']#['Size'] 
#print(trades_size) # shows the size of the trades
#plt.bar(trades_size, height=trades_size.count())
#plot = bt.plot(plot_volume=False)
#print(plot)
# Out:
# /tmp/ipykernel_1635/1481495050.py:39: UserWarning: Data index is not datetime. Assuming simple periods, but `pd.DateTimeIndex` is advised.
#   bt = Backtest(df40, MyStrat, cash=100, margin=1/50, commission = 0.00, trade_on_close=False)
# /tmp/ipykernel_1635/1481495050.py:35: RuntimeWarning: divide by zero encountered in double_scalars
#   size2 = (self.equity*self.riskpct)//(h - c)*self.contract_size
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# /tmp/ipykernel_1635/1481495050.py in <module>
#      38
#      39 bt = Backtest(df40, MyStrat, cash=100, margin=1/50, commission = 0.00, trade_on_close=False)
# ---> 40 stat = bt.run()
#      41 print(stat)
#      42 trades_size = stat['_trades']['Size']
#
# ~/miniconda3/envs/TRADING/lib/python3.9/site-packages/backtesting/backtesting.py in run(self, **kwargs)
#    1168
#    1169                 # Next tick, a moment before bar close
# -> 1170                 strategy.next()
#    1171             else:
#    1172                 # Close any remaining open trades so they produce some stats
#
# /tmp/ipykernel_1635/1481495050.py in next(self)
#      35             size2 = (self.equity*self.riskpct)//(h - c)*self.contract_size
#      36
# ---> 37             self.sell(limit=c, sl=h+4e-4, tp=c - 2*(c-1), size=int(size2))
#      38
#      39 bt = Backtest(df40, MyStrat, cash=100, margin=1/50, commission = 0.00, trade_on_close=False)
#
# OverflowError: cannot convert float infinity to integer

# %% [markdown]
# OPTIMIZATION

# %%
# Since Optimization takes some time to analize the data, I already have done it and the best parameters are: EMA=200, RSI=2

# stats = bt.optimize(
#     ema_window = [50, 200],
#     rsi_window = range(2, 4),
#     maximize = 'Equity Final [$]',
# )

# print(stats)
# print(stats._strategy)
# bt.plot(plot_volume=False, plot_pl=False)

# %% [markdown]
# CALCULATION OF POSITION SIZE BY RISK% AND SL SIZE

# %%
# c, h, o, l = self.data.Close[-1], self.data.High[-1], self.data.Open[-1], self.data.Low[-1]
# riskpct = 0.002
# contract_size = 100000
# size2 = (self.equity*riskpct)//(h - c)*contract_size
# size1 = (self.equity*riskpct)//(o - l)*contract_size

# %% [markdown]
# CALCULATION OF SL ON LOW AND HIGH OF SIGNAL CANDLE

# %%
# c, h, o, l = self.data.Close[-1], self.data.High[-1], self.data.Open[-1], self.data.Low[-1]
# self.sell(limit=c, sl=h+4e-4, tp=c - 2*(c-1), size=riskpct)
# self.buy(limit=c, sl=l-4e-4, tp=c + 2*(c-1), size=riskpct)
